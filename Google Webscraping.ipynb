# %%
#Import neccesary libraries

from selenium import webdriver              # driver to control chrome browser
from webdriver_manager.chrome import ChromeDriverManager
import pyautogui                            
from bs4 import BeautifulSoup          # to parse the html code
import threading                       # to do multi threding
import time 
import pandas as pd                   # to store data in csv file

# %%
#enter the filename

print("Enter the filename")            # filename to store data
filename=str(input())
# Out:
# Enter the filename
# dental_clinics

# %%
browser = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 88.0.4324
# [WDM] - Get LATEST driver version for 88.0.4324
# [WDM] - Driver [C:\Users\hp\.wdm\drivers\chromedriver\win32\88.0.4324.96\chromedriver.exe] found in cache

# %%
#intiate the chrome webdriver instance
#browser = webdriver.Chrome(executable_path='C:/Users/hp/chromedriver_win32/chromedriver.exe')     # chrome instance 
#browser.get('http://google.com/')

record=[]
e=[]          # chrome instance

# %%
def Selenium_extractor():
    time.sleep(2)
    a=browser.find_elements_by_class_name("VkpGBb")
    time.sleep(1)
    for i in range(len(a)):
        a[i].click()
        time.sleep(2)
        source=browser.page_source
                                                          #Beautiful soup for scraping the html source
        soup=BeautifulSoup(source,'html.parser')
        try:
            Name_Html=soup.findAll('div',{"class":"SPZz6b"})
            
            name=Name_Html[0].text
            if name not in e:
                e.append(name)
                print(name)
                Phone_Html=soup.findAll('span',{"class":"LrzXr zdqRlf kno-fv"})    
                phone=Phone_Html[0].text
                print(phone)
            
                Address_Html=soup.findAll('span',{"class":"LrzXr"})
                
                address=Address_Html[0].text
                #print(address)
                try:
                    Website_Html=soup.findAll('div',{"class":"QqG1Sd"})
                    web=Website_Html[0].findAll('a')
            
                    website=web[0].get('href')
                except:
                    website="Not available"
                #print(website)
                record.append((name,phone,address,website))
                df=pd.DataFrame(record,columns=['Name','Phone number','Address','Website'])  # writing data to the file
                df.to_csv(filename + '.csv',index=False,encoding='utf-8')

        except:
            print("error")
            continue
            

        
    try:
        time.sleep(1)            
        next_button=browser.find_element_by_id("pnnext")                  # clicking the next button
        next_button.click()
        browser.implicitly_wait(2)
        time.sleep(2)
        Selenium_extractor()
    except:
        print("ERROR occured at clicking net button")

# %%
print("Enter the link of the page")
link=input()
browser.get(str(link)) 
time.sleep(10)                                             # pausing the program for 10 secs
Selenium_extractor()
# Out:
# Enter the link of the page
# https://www.google.com/search?tbs=lf:1,lf_ui:2&tbm=lcl&sxsrf=ALeKk002wIrWc_qfYphip5YreKuXFh7Chg:1615442874659&q=dental+clinics+in+UAE&rflfq=1&num=10&sa=X&ved=2ahUKEwjBqsvVyafvAhXQfMAKHcVmCRgQjGp6BQgyEIkB&biw=1422&bih=657#rlfi=hd:;si:;mv:[[25.2948205,55.402694],[25.0311552,55.114353699999995]];tbs:lrf:!1m4!1u3!2m2!3m1!1e1!1m4!1u2!2m2!2m1!1e1!1m4!1u16!2m2!16m1!1e1!1m4!1u16!2m2!16m1!1e2!2m1!1e2!2m1!1e16!2m1!1e3!2m4!1e17!4m2!17m1!1e2,lf:1,lf_ui:2
# Dr. Michael's Children's Dental Center DubaiWebsiteDirections           Saved (0) Saved Save
# 04 339 7700
# The Dome MedDental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 399 9772
# Swedish Dental Clinic - Dubai MarinaWebsiteDirections           Saved (0) Saved Save
# 04 456 3366
# Ilham Dental Clinic Dubai Marina Diamond 3Directions           Saved (0) Saved Save
# 050 652 4440
# Dr. Thomas Dental Implant Clinic DMCC Dubai, UAEWebsiteDirections           Saved (0) Saved Save
# 04 452 5751
# Palmyra Dental ClinicDirections           Saved (0) Saved Save
# 04 457 1555
# Pearl Dental Clinic DubaiWebsiteDirections           Saved (0) Saved Save
# 04 427 0710
# Dental Studio – Al Wasl (formerly British Dental Clinic)WebsiteDirections           Saved (0) Saved Save
# 04 519 3700
# Dental Studio - Dubai MarinaWebsiteDirections           Saved (0) Saved Save
# 04 399 8440
# La Perla Dental Clinic in DubaiWebsiteDirections           Saved (0) Saved Save
# 04 432 1732
# Dr. Joy Dental Clinic Jumeirah DubaiWebsiteDirections           Saved (0) Saved Save
# 04 328 5332
# German Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 379 4722
# Crossroads Dental Clinic- Best Dental Clinic in Dubai Deira, Dentist near me Veneers, Rct, Invisalign Clear AlignerWebsiteDirections           Saved (0) Saved Save
# 04 294 9757
# New York Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 344 7041
# Sky Clinic Dental Center JLT - German Dentist Dubai - Dentists in DubaiWebsiteDirections           Saved (0) Saved Save
# 04 704 8000
# Dr. Michael's Dental Clinic - Umm Suqeim DubaiWebsiteDirections           Saved (0) Saved Save
# 04 394 9433
# hnc dental clinicWebsiteDirections           Saved (0) Saved Save
# 052 151 4300
# Vienna Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 589 7990
# Akeela Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 422 9009
# Dubai Dental HospitalWebsiteDirections           Saved (0) Saved Save
# 800 336825
# Best Dental Clinic LLC - Karama Dubai, Teeth Whitening, Tooth Filling, Dentist Braces, DentureWebsiteDirections           Saved (0) Saved Save
# 04 358 8965
# ORTHODONTIX DENTAL CLINIC - DubaiWebsiteDirections           Saved (0) Saved Save
# 050 184 1423
# Royal Dentists Center - Dubai
# 04 399 8440
# Shams Moopen Dental Clinic ( Top Rated Dental Clinic )WebsiteDirections           Saved (0) Saved Save
# 04 399 7522
# ARAKS DENTAL CLINIC DMCCWebsiteDirections           Saved (0) Saved Save
# 04 565 5134
# Clover Medical Centre-Dental & OrthodontistWebsiteDirections           Saved (0) Saved Save
# 04 368 8062
# IMED Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 050 484 5472
# Precision Dental Clinic - DubaiWebsiteDirections           Saved (0) Saved Save
# 04 275 6731
# Versailles Dental Clinic - Dental Clinic in DubaiWebsiteDirections           Saved (0) Saved Save
# 04 429 8288
# Klinika Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 347 4339
# American Medical & Dental Center (AMDC)WebsiteDirections           Saved (0) Saved Save
# 04 374 8428
# Hollywood Smile Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 351 0102
# Apex Medical and Dental ClinicsWebsiteDirections           Saved (0) Saved Save
# 04 360 8881
# Dr. Roze & Associates Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 388 1313
# Empire Dental Clinic DubaiWebsiteDirections           Saved (0) Saved Save
# 04 276 6577
# American Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 344 0668
# Dental Studio Dubai - Umm Al SheifWebsiteDirections           Saved (0) Saved Save
# 04 395 5095
# NOA Dental Clinic DubaiWebsiteDirections           Saved (0) Saved Save
# 04 398 7075
# Smile Dental Clinic, Mirdif, Dubai, UAEWebsiteDirections           Saved (0) Saved Save
# 04 226 9474
# Go Dental Clinic (A part of Dr. Joy Dental Clinic group)WebsiteDirections           Saved (0) Saved Save
# 04 397 9522
# Dr Joan Dental Clinic, Dubai, Best Medical Centre, Teeth Whitening, Filipino DentalWebsiteDirections           Saved (0) Saved Save
# 04 358 8965
# Standard Medical Clinic - Dental Clinic in DubaiWebsiteDirections           Saved (0) Saved Save
# 04 328 1112
# Dental Studio - TecomWebsiteDirections           Saved (0) Saved Save
# 04 368 7070
# Dr. Paul's Dental Clinic DubaiWebsiteDirections           Saved (0) Saved Save
# 04 357 5783
# Al Dana Medical Poly ClinicWebsiteDirections           Saved (0) Saved Save
# 055 574 2142
# Shine & Smile Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 224 2100
# Dental Clinic Lounge in Al Karama, Dentist in Dubai, Braces, Teeth whitening, Tooth crown, Extraction, Cleaning, Retainers, DenturesWebsiteDirections           Saved (0) Saved Save
# 04 397 0883
# Dr. Luis Gavin (Dental Maxillofacial Aesthetic)WebsiteDirections           Saved (0) Saved Save
# 056 704 8581
# Dubai Smile Dental Clinic | Dubai
# 04 380 8988
# Easy Dental Clinic in Karama - Dentist in Dubai - Karama Dentist - Braces - Teeth Whitening - Tooth Filling - Dentures - RetainersWebsiteDirections           Saved (0) Saved Save
# 04 388 5989
# Dr. Joy Dental Clinic Mirdif DubaiWebsiteDirections           Saved (0) Saved Save
# 04 284 5722
# Dr Maya Dental Clinic Motor City DubaiWebsiteDirections           Saved (0) Saved Save
# 04 554 6394
# Dentzz Dental Care Centre - DubaiWebsiteDirections           Saved (0) Saved Save
# 055 999 8189
# Mankhool Dental ClinicDirections           Saved (0) Saved Save
# 04 357 1577
# Clinic for Cosmetic Dentistry
# 04 429 8400
# Dr. Ehab's Dental Clinic BeClinique DubaiWebsiteDirections           Saved (0) Saved Save
# 04 346 1546
# Al Reem Clinic DubaiDirections           Saved (0) Saved Save
# 04 385 0250
# Oracare Dental Clinic
# 04 399 5997
# Dr. Mohamed Rafi Dental Clinic
# 04 379 7934
# Smile Essentials Dental Clinic, DubaiWebsiteDirections           Saved (0) Saved Save
# 056 484 8613
# Easy Dental Clinic Satwa, Dubai Braces, Filling, Best Dentist whitening teeth, tooth removal, Orthodontist in sheikh zayed rd Dubai, Braces specialist in sheikh zayed rd.WebsiteDirections           Saved (0) Saved Save
# 04 355 0588
# Dr. Anand Shenoy Dental Clinic - Motor City BranchWebsiteDirections           Saved (0) Saved Save
# 04 422 6926
# Dubai Sky Clinic, BurjumanWebsiteDirections           Saved (0) Saved Save
# 04 355 8808
# Best Dentist LLC, Al Rigga - Dubai, Dental Clinic in Deira, Braces, Teeth Whitening, Tooth Filling, Dental Clinic In Al Rigga, Dental Crown, Teeth CleaningWebsiteDirections           Saved (0) Saved Save
# 04 251 7887
# Pearly white Dental Clinic
# 055 104 4364
# Dr. Joy Dental Clinic BurJuman DubaiWebsiteDirections           Saved (0) Saved Save
# 04 355 5357
# Levantine Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 338 5677
# Italian Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 458 0040
# Lotus Dental Clinic in Al Nahda Dubai | عيادة اسنانWebsiteDirections           Saved (0) Saved Save
# 04 397 1667
# The Smile Studio Dental ClinicDirections           Saved (0) Saved Save
# 056 488 8466
# Clove Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 343 5424
# Dr. Michael's Dental Clinic - Jumeirah DubaiWebsiteDirections           Saved (0) Saved Save
# 04 349 5900
# Trusmile Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 050 481 7488
# Luxe Dental Clinic 24/7 dental emergency
# 056 162 6254
# Florida Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 06 556 2966
# Swiss Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 332 1444
# Dr. Joy Dental Clinic - Palm JumeirahWebsiteDirections           Saved (0) Saved Save
# 04 243 5888
# New Ivory Dental and Implant ClinicWebsiteDirections           Saved (0) Saved Save
# 04 349 3313
# German Dental OasisWebsiteDirections           Saved (0) Saved Save
# 04 363 5367
# Lookswoow Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 448 7016
# Pretty Smile Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 886 6248
# Oris Dental CentreWebsiteDirections           Saved (0) Saved Save
# 04 380 9990
# Paramount Dental ClinicDirections           Saved (0) Saved Save
# 02 622 8724
# Black Diamond Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 399 3311
# Apex Dental & Orthodontic ClinicWebsiteDirections           Saved (0) Saved Save
# 04 240 7333
# Drs. Nicolas & Asp - Marina Walk, Dental & MedicalWebsiteDirections           Saved (0) Saved Save
# 04 360 9977
# Dubai Smile Dental Clinic -Mirdif Branch
# 04 394 9655
# Luxe Dental Clinic in DubaiWebsiteDirections           Saved (0) Saved Save
# 04 358 0885
# Micris Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 330 0441
# The Lakes ClinicWebsiteDirections           Saved (0) Saved Save
# 04 453 4848
# Al Dehyafa Specialized Orthodontic and Dental Clinic branch alhudaiba عيادة الضيافة لطب الأسنان فرع الحضيبة
# 04 343 4342
# Harley Street Dental CenterWebsiteDirections           Saved (0) Saved Save
# 02 491 6885
# True Smile Works Dental NetworkWebsiteDirections           Saved (0) Saved Save
# 04 222 2866
# North Carolina Dental PracticeWebsiteDirections           Saved (0) Saved Save
# 04 363 5328
# HEY Dental Clinic - DMCCWebsiteDirections           Saved (0) Saved Save
# 04 450 8717
# Blue Dental Clinic
# 04 394 4233
# ConfiDent Dental & Skin Care ClinicWebsiteDirections           Saved (0) Saved Save
# 04 343 3315
# Marina Dental Center
# 04 369 3625
# Royal Dental CareDirections           Saved (0) Saved Save
# 04 385 4422
# Dentacare Centre (Dental & Orthodontics) HamdanWebsiteDirections           Saved (0) Saved Save
# 02 627 0527
# Canadian Specialized Dental CenterDirections           Saved (0) Saved Save
# 04 428 1499
# International Dental Clinic Dubai - Anchassy SmileWebsiteDirections           Saved (0) Saved Save
# 04 343 3360
# Dr Tosun Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 343 5051
# Clover Medical Centre Al Nahda (Dental Clinic)WebsiteDirections           Saved (0) Saved Save
# 052 785 9888
# Infinity Dental Center JLT/ Microscopic DentistryWebsiteDirections           Saved (0) Saved Save
# 04 448 9270
# DXD Dental Clinic DubaiDirections           Saved (0) Saved Save
# 04 326 6576
# Magnum Gulf Medical Center, Silicon Oasis DSOWebsiteDirections           Saved (0) Saved Save
# 04 397 3738
# Dentist Direct DubaiWebsiteDirections           Saved (0) Saved Save
# 04 455 9398
# 24 Hours Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 355 4466
# Bin Arab Dental Centre, Fairmont DubaiWebsiteDirections           Saved (0) Saved Save
# 04 320 2008
# McGill Dental CenterWebsiteDirections           Saved (0) Saved Save
# 04 277 6055
# Specialized Medical & Dental Centre, Dubai, UAEWebsiteDirections           Saved (0) Saved Save
# 04 327 8111
# Clover Medical Centre - Bur Dubai (Dental Clinic)WebsiteDirections           Saved (0) Saved Save
# 052 212 8880
# Drs. Nicolas & Asp - Uptown Mirdif, Dubai - Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 255 9977
# Easy Dental Clinic Al Rigga - Best Dentist Braces Dubai teeth Whitening tooth Removal, DeiraWebsiteDirections           Saved (0) Saved Save
# 04 295 1797
# LUZAN DENTAL CENTERWebsiteDirections           Saved (0) Saved Save
# 04 331 1116
# Dr. Mallya's Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 351 2525
# Hellenic Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 349 0422
# Smile Dental Clinic Dubai
# 052 661 5030
# Best dental implants in dubai
# 04 394 5422
# Bright Way Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 055 497 1986
# Dubai Specialized Dental Center
# 04 590 8500
# MUNICH DENTAL CLINIC DubaiWebsiteDirections           Saved (0) Saved Save
# 04 345 0055
# Dentaline Clinic Knowledge village
# 04 368 5628
# British Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 02 677 3308
# French Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 429 8218
# Snö Dental ClinicsWebsiteDirections           Saved (0) Saved Save
# 800 3368478
# GMCClinics - Trade Centre ApartmentsWebsiteDirections           Saved (0) Saved Save
# 04 331 3544
# Alabama Dental Center
# 04 394 8222
# Legacy Dental CenterWebsiteDirections           Saved (0) Saved Save
# 04 514 8190
# Dubai Smile Dental Clinic - Al Ain
# 03 763 4445
# Best Dental Clinic LLC in Al Rigga, Dentist Deira, Braces, Teeth Crown, Retainer, Teeth CleaningWebsiteDirections           Saved (0) Saved Save
# 04 327 0888
# Lebanon Medical Center- المركز اللبناني الطبي
# 04 228 8766
# Dental Clinic in Silicon Oasis
# 04 397 3738
# Oval Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 340 0900
# Kings Dental Center Karama DubaiWebsiteDirections           Saved (0) Saved Save
# 058 568 1943
# SameDay Dental Implants Clinic, Dubai سيمداي لزراعة الأسنانWebsiteDirections           Saved (0) Saved Save
# 04 315 8300
# Smilerite Dental CareWebsiteDirections           Saved (0) Saved Save
# 02 555 9595
# Dr. Hussein Labib Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 269 9953
# Dubai London Clinic Dental CentreWebsiteDirections           Saved (0) Saved Save
# 800 352
# Munich Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 345 4400
# Dr Gad Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 054 383 5666
# Bourgeois ClinicWebsiteDirections           Saved (0) Saved Save
# 04 385 3383
# Al Ula Clinic Best Dental Clinic in Dubai karama, Dentist near me Veneers, Rct, Invisalign Clear AlignerBest Dental Clinic LLC - Karama Dubai, Teeth Whitening, Tooth Filling, Dentist Braces, DentureDirections           Saved (0) Saved Save
# 04 396 7828
# Luminance Dental CenterWebsiteDirections           Saved (0) Saved Save
# 04 557 8998
# GYA dental centerWebsiteDirections           Saved (0) Saved Save
# 04 228 4631
# Scandinavian Dental Clinic - العيادة الاسكندنافيةWebsiteDirections           Saved (0) Saved Save
# 04 349 3202
# Dental Studio - Jumeirah Beach RoadWebsiteDirections           Saved (0) Saved Save
# 04 395 2524
# Dr. Marat AzizovWebsiteDirections           Saved (0) Saved Save
# 04 363 5367
# Al Saha Dental Clinic
# 06 568 4322
# Crystal White Specialty Dental Clinic
# 04 552 0059
# Dr.MANJULAS DENTAL CLINICWebsiteDirections           Saved (0) Saved Save
# 050 598 8174
# Dubai Smile Dental Clinic - Al Ain Br ابتسامة دبي فرع العين
# 03 763 4445
# Aspetar Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 02 551 1219
# American Excellence Medical & Dental Center
# 02 658 2228
# Dr. Rafih Khoury Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 398 2000
# All Smiles Dental Spa DubaiWebsite           Saved (0) Saved Save
# 056 237 5568
# Dental emergency 24/7 at Northwest ClinicWebsiteDirections           Saved (0) Saved Save
# 056 665 6889
# Drs. Nicolas & Asp - Springs Souk Center,Dental & MedicalWebsiteDirections           Saved (0) Saved Save
# 04 557 2949
# Dr. Aburas Dental CenterWebsiteDirections           Saved (0) Saved Save
# 04 395 2131
# Advanced American Dental CenterWebsiteDirections           Saved (0) Saved Save
# 02 681 2921
# Vision Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 052 999 2283
# Tower ClinicWebsiteDirections           Saved (0) Saved Save
# 04 362 2939
# Dubai Hollywood Smiles (Previously Charly PolyClinic)Directions           Saved (0) Saved Save
# 050 213 9191
# Oxford Medical Center Dubai UAEWebsiteDirections           Saved (0) Saved Save
# 04 351 1164
# GMCClinics - Jumeirah DentalWebsiteDirections           Saved (0) Saved Save
# 04 344 9150
# Avance Dental - Best Dentists in Al Rigga, Dubai - Dental Care, Teeth Whitening, Braces, RemovalWebsiteDirections           Saved (0) Saved Save
# 04 266 6022
# Liberty Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 395 5009
# Smile Spa Dental Clinic
# 04 236 2337
# Whitefield Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 02 681 3101
# Boston Dental CenterWebsiteDirections           Saved (0) Saved Save
# 02 666 7070
# Medical Center Dubai
# 04 355 5308
# Bissan Dental CenterWebsiteDirections           Saved (0) Saved Save
# 04 374 3388
# Joy Dental Clinic, Dr
# 04 397 9522
# Dr. Mohannad Dental Clinic
# 04 289 9441
# Dr. Joy Pediatric & Orthodontic CenterWebsiteDirections           Saved (0) Saved Save
# 04 346 8333
# Dr Shadi Alshaikh Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 056 717 1707
# Dental Home LLC
# 04 358 7000
# Montreal International Clinic
# 04 344 1132
# ALZAHRAA DENTAL & ORTHODONTIC CLINIC
# 052 118 7766
# Jumeira Beach Dental CenterWebsiteDirections           Saved (0) Saved Save
# 04 349 9433
# Magic Style Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 243 6366
# Dr. Hibah Shata Specialized Dental Clinic
# 04 295 9790
# Al Garhoud Private Hospital Clinic Shorooq | Skin Specialist In Dubai | Best Dental Clinic In DubaiDirections           Saved (0) Saved Save
# 04 243 2180
# Davinci Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 02 222 2616
# Pearl Medical ClinicWebsiteDirections           Saved (0) Saved Save
# 04 224 9481
# The Clinic DIFCWebsiteDirections           Saved (0) Saved Save
# 04 323 0900
# Sara Dental ClinicDirections           Saved (0) Saved Save
# 06 553 5717
# Al Mariffa Medical CentreWebsiteDirections           Saved (0) Saved Save
# 04 252 2133
# Dr. Rocco's Specialized Dental CenterWebsiteDirections           Saved (0) Saved Save
# 02 633 2900
# Magnum Gulf Medical CenterWebsiteDirections           Saved (0) Saved Save
# 054 336 3340
# Dr. Jacks Dental Clinic
# 04 227 7588
# Bay Avenue Dental Centre
# 04 277 0247
# Dental Experts CenterWebsiteDirections           Saved (0) Saved Save
# 02 681 0060
# German Dental CenterWebsiteDirections           Saved (0) Saved Save
# 04 449 5335
# Veneto ClinicWebsiteDirections           Saved (0) Saved Save
# 058 950 2469
# Maher Medical Centre - Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 02 666 3588
# Hikma Medical Center - Dental (Mushrif)WebsiteDirections           Saved (0) Saved Save
# 02 447 4400
# 7DMC Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 243 4777
# Drs. Nicolas & Asp - Jumeirah - Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 394 7777
# Al Badia Dental ClinicDirections           Saved (0) Saved Save
# 04 283 0777
# Smile Bay Dental CafeDirections           Saved (0) Saved Save
# 04 330 5553
# McBody Clinic – Best Cosmetic/ Plastic Surgery || Dental Clinic || Weight loss || Bariatric Surgery || Dietitian & MoreWebsiteDirections           Saved (0) Saved Save
# 04 385 5552
# Dubai Smile Al ain Br ابتسامة دبي في العين
# 03 763 4445
# Nagem Dental CenterWebsiteDirections           Saved (0) Saved Save
# 04 456 4090
# Dubai Smile Dental Clinic | Abu Dhabi | عيادة ابتسامة دبي
# 02 665 0555
# Bright Smile CenterWebsiteDirections           Saved (0) Saved Save
# 04 344 9675
# Maral Dental Center
# 04 250 2011
# BE YOU CLINICWebsiteDirections           Saved (0) Saved Save
# 04 607 6700
# Dentacare Centre - Muroor (عيادة الأسنان مركز دنتكير)WebsiteDirections           Saved (0) Saved Save
# 02 443 2525
# AL TAEF EAST MEDICAL CENTRE
# 04 333 4418
# Bella Vita Dental Clinic | مركز بيلا فيتا لطب وتقويم الأسنانWebsiteDirections           Saved (0) Saved Save
# 052 665 5963
# Kamilia PolyclinicWebsiteDirections           Saved (0) Saved Save
# 050 160 0361
# Thomas Dental CentreWebsiteDirections           Saved (0) Saved Save
# 02 641 4400
# MAG ClinicWebsiteDirections           Saved (0) Saved Save
# 04 379 4444
# Al Bahri Dental and Orthodontic CenterWebsiteDirections           Saved (0) Saved Save
# 03 764 3273
# Rona Rabah Dental ClinicWebsiteDirections           Saved (0) Saved Save
# 04 558 6998
# Vida ClinicsWebsiteDirections           Saved (0) Saved Save
# 04 325 2525
# Smilecare Medical CenterWebsiteDirections           Saved (0) Saved Save
# 06 577 5262
# AlSham Medical Center (Dental Clinics)Directions           Saved (0) Saved Save
# 06 567 8977
# New Al Shefa Clinic - Best Ophthalmologist Dubai - Eye Specialist - Dental Implants Dubai - Laser Hair RemovalWebsiteDirections           Saved (0) Saved Save
# 04 394 2211
# Gentle Dental and Medical Care CenterWebsiteDirections           Saved (0) Saved Save
# 02 676 4642
# Choufani Dental PolyclinicWebsiteDirections           Saved (0) Saved Save
# 03 722 9005
# Happiness Dental ClinicDirections           Saved (0) Saved Save
# 04 334 4065
# Emirates Royal Orthodontic & Cosmetic Dentistry Center
# 02 666 4544
# Abu Dhabi Dental Center مركز أبوظبي لطب الأسنانWebsiteDirections           Saved (0) Saved Save
# 800 50
# University Dental Hospital SharjahWebsiteDirections           Saved (0) Saved Save
# 06 505 7666
# Dentaline Clinic
# 04 227 7718
# Dr. Omar Aldaoudi - Specialist ProsthodontistDirections           Saved (0) Saved Save
# 04 519 3700
# Dubai Star PolyclinicWebsiteDirections           Saved (0) Saved Save
# 04 284 4242
# Dr.Al Jundi Orthodontic & Dental CentreWebsiteDirections           Saved (0) Saved Save
# 02 666 5357
# GMCClinics TecomWebsiteDirections           Saved (0) Saved Save
# 04 567 6888
# Dubai Smile Dental Clinic
# 02 665 0555
# Kings Medical Center (Dental, Dermatology, Laser Hair Removal)WebsiteDirections           Saved (0) Saved Save
# 04 255 2020
# Tajmeel Dental CenterWebsiteDirections           Saved (0) Saved Save
# 02 610 7878
# GMCClinics - Green CommunityWebsiteDirections           Saved (0) Saved Save
# 04 393 2983
# American Excellence Medical and Dental CenterWebsiteDirections           Saved (0) Saved Save
# 04 395 5113
# Dr. Roze & Associates ClinicsWebsiteDirections           Saved (0) Saved Save
# 04 385 8081
# IMC Medical Center | IMC Clinic Albarsha, DubaiWebsiteDirections           Saved (0) Saved Save
# 04 332 0007
# iCARE Clinic - Oasis CentreWebsiteDirections           Saved (0) Saved Save
# 800 42273
# Dr. Ihab William Dentist
# 050 150 9211
# Basmat Al Bayan Medical CenterWebsiteDirections           Saved (0) Saved Save
# 04 343 4701
# Medicentres MotorcityWebsiteDirections           Saved (0) Saved Save
# 04 429 8888
# Dr. Rasool Healthcare Centre
# 04 223 3304
# King's College Hospital DubaiWebsiteDirections           Saved (0) Saved Save
# 04 247 7777
# Noor Al Wasl ClinicWebsiteDirections           Saved (0) Saved Save
# 04 395 3900
# Marina Medical Center, Dubai Marina ClinicsWebsiteDirections           Saved (0) Saved Save
# 04 399 9939
# Queens Medical CenterWebsiteDirections           Saved (0) Saved Save
# 04 353 3101
# Dr Sameer H Shaikh orthodontist
# 052 212 8880
# Bella Medical Centre - Invisalign in Abu Dhabi, Dental & Dermatology Clinic.WebsiteDirections           Saved (0) Saved Save
# 02 666 3676
# New Al Shefa Clinic - Cosmetic Dermatologist Dubai - Laser Hair RemovalWebsiteDirections           Saved (0) Saved Save
# 04 345 3399
# Masters Dental and Aesthetic Center
# 02 444 8433
# DrKamkar clinicWebsiteDirections           Saved (0) Saved Save
# 056 526 4659
# New Al Shefa Clinic JLT - Aesthetic Plastic Surgery Dubai - Cosmetic Surgery - Laser Hair Removal DubaiWebsiteDirections           Saved (0) Saved Save
# 04 362 4247
# Dr. Sai Ganesh Medical Center - DeiraWebsiteDirections           Saved (0) Saved Save
# 04 256 0866
# Dr. Maen AburasWebsiteDirections           Saved (0) Saved Save
# 04 395 2131
# GMCClinics - Jumeirah MedicalWebsiteDirections           Saved (0) Saved Save
# 04 349 4880
# Medical Specialists CentreWebsiteDirections           Saved (0) Saved Save
# 04 345 4040
# Ugarit Dental CenterWebsiteDirections           Saved (0) Saved Save
# 06 533 5055
# iCARE ClinicWebsiteDirections           Saved (0) Saved Save
# 800 42273
# Somerset Clinic DubaiWebsiteDirections           Saved (0) Saved Save
# 04 361 2404
# The Perio ClinicWebsiteDirections           Saved (0) Saved Save
# 04 442 8515
# Dr. Anju
# 04 343 5424
# uniCare Medical Centre | Top medical centre in Dubai - Mankhool BranchDirections           Saved (0) Saved Save
# 04 352 9292
# New Bhatia Medical Centre I Best Pediatric Dentist in SharjahWebsiteDirections           Saved (0) Saved Save
# 06 524 2550
# Snö Clinics
# 02 493 6700
# 32 Smiles Dental CenterWebsiteDirections           Saved (0) Saved Save
# 02 445 4666
# Al Ain Dental Center- مركز العين لطب الأسنانWebsiteDirections           Saved (0) Saved Save
# 800 50
# CITY MEDICAL CENTREWebsiteDirections           Saved (0) Saved Save
# 04 283 1611
# Magnum Family Medical Center
# 054 336 3340
# Dr. Roaa TalalWebsiteDirections           Saved (0) Saved Save
# 04 243 4777
# Al Mansoor Medical CenterDirections           Saved (0) Saved Save
# 04 355 4040
# HMC Medical CenterWebsiteDirections           Saved (0) Saved Save
# 04 566 8336
# Dental NMC Hospital, Sama Tower
# error
# MyPediaClinicWebsiteDirections           Saved (0) Saved Save
# 055 931 1752
# Dr Abdulla's Clinic
# 054 598 1431
# Healers Medical Center LLCWebsiteDirections           Saved (0) Saved Save
# 06 553 9851
# 7 Dimensions Medical Centre (Seven Dimensions)WebsiteDirections           Saved (0) Saved Save
# 050 137 7000
# Al Dhafra Dental Center - مركز الظفرة لطب الاسنانWebsiteDirections           Saved (0) Saved Save
# 800 50
# Globehealth General ClinicWebsiteDirections           Saved (0) Saved Save
# 04 346 4180
# ToothsmithsWebsiteDirections           Saved (0) Saved Save
# 055 397 8923
# Glow Medical And Dental Centre -tecom
# 04 456 4889
# Mediclinic Al Madar
# 03 762 8899
# Icon Clinic - Abu DhabiWebsiteDirections           Saved (0) Saved Save
# 050 120 4012
# Wellbeing Medical CentreWebsiteDirections           Saved (0) Saved Save
# 04 348 4406
# Mediclinic Dubai Mall
# 04 449 5111
# Roya Medical CenterWebsiteDirections           Saved (0) Saved Save
# 04 345 5251
# SEHA Clinic - Khalifa City
# 800 50
# Med Art Clinic Day Surgery Center Dubai BranchWebsiteDirections           Saved (0) Saved Save
# 800 633278
# Royal European Polyclinic - العيادة الملكية الأوروبيةWebsiteDirections           Saved (0) Saved Save
# 04 341 5005
# Midac Medical CenterWebsiteDirections           Saved (0) Saved Save
# 04 285 7333
# uniCare Medical Centre | Best Doctors Dubai | Top Medical Centre In DubaiWebsiteDirections           Saved (0) Saved Save
# 04 352 9292
# TruCare ClinicsWebsiteDirections           Saved (0) Saved Save
# 04 347 5336
# DrFive
# error
# Al Marfa Al Ahli Medical Centre
# 02 883 3638
# Mediclinic City Hospital
# 800 1999
# Euromed Clinic DubaiWebsiteDirections           Saved (0) Saved Save
# 04 394 5422
# Dr Sunny Medical Centre- SharjahWebsiteDirections           Saved (0) Saved Save
# 06 566 8966
# Harley Street Medical CentreWebsiteDirections           Saved (0) Saved Save
# 02 613 3999
# KindCare Medical CenterWebsiteDirections           Saved (0) Saved Save
# 04 338 8588
# Mediclinic Al Yahar
# 800 2000
# Jawdah Medical Center
# error
# 𝐇𝐞𝐚𝐥𝐭𝐡𝐇𝐮𝐛 𝐂𝐥𝐢𝐧𝐢𝐜 | 𝐈𝐧𝐭𝐞𝐫𝐧𝐚𝐭𝐢𝐨𝐧𝐚𝐥 𝐂𝐢𝐭𝐲WebsiteDirections           Saved (0) Saved Save
# 04 571 4100
# 𝐇𝐞𝐚𝐥𝐭𝐡𝐇𝐮𝐛 𝐂𝐥𝐢𝐧𝐢𝐜 | 𝐒𝐢𝐥𝐢𝐜𝐨𝐧 𝐎𝐚𝐬𝐢𝐬
# 800 2344
# Ajman University dental clinic
# 06 705 6289
# Care Plus Medical Center - Jebel Ali
# 04 882 9333
# Clinica Joelle Abu DhabiWebsiteDirections           Saved (0) Saved Save
# 02 666 6988
# Saudi German Clinics JumeirahWebsiteDirections           Saved (0) Saved Save
# 800 2211
# Al Das Medical ClinicWebsiteDirections           Saved (0) Saved Save
# 04 452 9998
# HealthBay Al Wasl
# 04 348 7140
# المركز التخصصي لطب وتقويم الاسنان Specialized Dental and Orthodontic Centre
# 02 443 9688
# Mediclinic Deira
# 04 605 5999
# Emirates Specialty HospitalWebsiteDirections           Saved (0) Saved Save
# 04 248 4500
# 𝐇𝐞𝐚𝐥𝐭𝐡𝐇𝐮𝐛 𝐂𝐥𝐢𝐧𝐢𝐜 | 𝐀𝐥 𝐖𝐚𝐫𝐪𝐚WebsiteDirections           Saved (0) Saved Save
# 04 218 6222
# Clinica Joelle DubaiWebsiteDirections           Saved (0) Saved Save
# 04 338 8904
# 𝐇𝐞𝐚𝐥𝐭𝐡𝐇𝐮𝐛 𝐂𝐥𝐢𝐧𝐢𝐜 | 𝐀𝐥 𝐐𝐮𝐬𝐚𝐢𝐬WebsiteDirections           Saved (0) Saved Save
# 04 204 0400
# Abeer Al Noor Polyclinic MuhaisnahWebsiteDirections           Saved (0) Saved Save
# 04 272 9966
# Cure North
# 02 410 0900
# Dr. VladimirWebsiteDirections           Saved (0) Saved Save
# 04 378 6666
# Advanced Care Medical Center (Br.) DIPWebsiteDirections           Saved (0) Saved Save
# 04 885 0788
# Ideal Medical CenterWebsiteDirections           Saved (0) Saved Save
# 06 562 3844
# DR PEGAH DEHDARIWebsiteDirections           Saved (0) Saved Save
# 056 258 6233
# Meddy UAE
# error
# Al-Futtaim health Corporate Office | Festival City MallWebsiteDirections           Saved (0) Saved Save
# 800 23344
# NMC Deira
# 04 233 9900
# Elite Plastic & Cosmetic Surgery Group | Compassionate Care You Can Trust | DubaiWebsiteDirections           Saved (0) Saved Save
# 04 431 2396
# Mediclinic Khalifa City
# 800 2000
# Dynamic PRP Therapy Clinic DubaiWebsiteDirections           Saved (0) Saved Save
# 04 584 1177
# Emirates HospitalWebsiteDirections           Saved (0) Saved Save
# 800 444444
# Ahalia Hospital Abu Dhabi- Hamdan Street
# 02 626 2666
# DNA Health & Wellness - JumeirahWebsiteDirections           Saved (0) Saved Save
# 04 573 6500
# NMC Royal Medical CentreWebsiteDirections           Saved (0) Saved Save
# 800 2273
# Aster Cedars Hospital, Jebel AliWebsiteDirections           Saved (0) Saved Save
# 04 440 0500
# Ugarit Dental Center
# 06 533 5055
# Al Muwaiji Healthcare CenterWebsiteDirections           Saved (0) Saved Save
# 800 50
# Medeor 24x7 Hospital - 24x7 مستشفى ميديورWebsiteDirections           Saved (0) Saved Save
# 800 55
# Emirates Specialty Hospital Clinic
# 04 248 4500
# American Hospital Al Khawaneej Clinic
# 04 377 5500
# Avivo GroupWebsiteDirections           Saved (0) Saved Save
# 04 370 5080
# Emirates Hospital Day Surgery & Medical Center
# 04 871 6900
# Aster Day Surgery CenterWebsiteDirections           Saved (0) Saved Save
# 04 440 0500
# 7DMC Dermatology & Aesthetics ClinicWebsiteDirections           Saved (0) Saved Save
# 04 243 4777
# Prime Hospital - Multi Specialty Private Hospital Dubai | Top Medical Centre UAE
# 04 292 9777
# ERROR occured at clicking net button
